# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

# %%
cd C:\Users\Dell\Desktop\Advanced Machine Learning\Practical 2
# Out:
# C:\Users\Dell\Desktop\Advanced Machine Learning\Practical 2

# %%
df = pd.read_csv('Houses_train.csv')
df.head()
# Out:
#    Unnamed: 0     price       condition district  max_floor           street  \
# 0        5546  130000.0  newly repaired   Center          4   Sayat Nova Ave
# 1        2979   65000.0            good  Arabkir          5     Hr.Kochar St
# 2        2698  129000.0            good   Center         10  M.Khorenatsi St
# 3        4548   52000.0  newly repaired   Center         14      Argishti St
# 4        2982   65000.0  newly repaired   Center         12     Mashtots Ave
#
#    num_rooms   region  area  \
# 0          3  Yerevan  96.0
# 1          3  Yerevan  78.0
# 2          3  Yerevan  90.0
# 3          2  Yerevan  53.0
# 4          2  Yerevan  47.0
#
#                                                  url  num_bathrooms  \
# 0  http://www.myrealty.am/en/item/28244/3-senyaka...              1
# 1  http://www.myrealty.am/en/item/18029/3-senyaka...              1
# 2  http://www.myrealty.am/en/item/37797/3-senyaka...              1
# ...

# %%
df.nunique()
# Out:
# Unnamed: 0        5000
# price              333
# condition            3
# district            13
# max_floor           23
# street             336
# num_rooms            6
# region               1
# area               122
# url               5000
# num_bathrooms        4
# building_type        4
# floor               20
# ceiling_height       5
# dtype: int64

# %%
df=df.drop(['region','url','Unnamed: 0'],axis=1)
df.head()
# Out:
#       price       condition district  max_floor           street  num_rooms  \
# 0  130000.0  newly repaired   Center          4   Sayat Nova Ave          3
# 1   65000.0            good  Arabkir          5     Hr.Kochar St          3
# 2  129000.0            good   Center         10  M.Khorenatsi St          3
# 3   52000.0  newly repaired   Center         14      Argishti St          2
# 4   65000.0  newly repaired   Center         12     Mashtots Ave          2
#
#    area  num_bathrooms building_type  floor  ceiling_height
# 0  96.0              1         stone      3             3.2
# 1  78.0              1         stone      2             2.8
# 2  90.0              1         panel      3             2.8
# 3  53.0              1       monolit      5             3.0
# 4  47.0              1         panel      3             2.8

# %%
df['condition'].value_counts()
# Out:
# newly repaired    2867
# good              1713
# zero condition     420
# Name: condition, dtype: int64

# %%
df['district'].value_counts()
# Out:
# Center              2086
# Arabkir             1320
# Avan                 252
# Malatia-Sebastia     235
# Davtashen            235
# Nor Norq             233
# Qanaqer-Zeytun       201
# Achapnyak            192
# Shengavit            163
# Erebuni               75
# Norq Marash            5
# Vahagni district       2
# Nubarashen             1
# Name: district, dtype: int64

# %%
df['max_floor'].value_counts()
# Out:
# 5     1356
# 9     1009
# 4      501
# 14     448
# 10     325
# 16     261
# 12     193
# 6      165
# 11     152
# 7      121
# 13     101
# 15      80
# 3       61
# 8       58
# 17      45
# 18      41
# 19      17
# 21      16
# 23      14
# 22      14
# 2       12
# 20       6
# 1        4
# Name: max_floor, dtype: int64

# %%
df['street'].value_counts()
# Out:
# Komitas Ave            255
# Mashtots Ave           147
# Tsarav Aghbyur St      113
# Sayat Nova Ave         113
# Mamikoniants St        106
#                       ...
# Fuchik 2 alley           1
# Muradyan St              1
# Vardanants alley         1
# Alixanyan exbayrner      1
# Nubarashen 5 St          1
# Name: street, Length: 336, dtype: int64

# %%
if type(df.columns[1])==str:
    print(df.value_counts())
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-43-fab3663b11cc> in <module>
#       1 if type(df.columns[1])==str:
# ----> 2     print(df.value_counts())
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5272             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5273                 return self[name]
# -> 5274             return object.__getattribute__(self, name)
#    5275
#    5276     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'value_counts'

# %%
def val_counts(df, col):
    df_vc=pd.DataFrame(df[col].value_counts())
    df_vc.index.name=col
    df.columns=['count']
    return df_vc

# %%
val_counts(df,df.columns)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-58-5568774eb79c> in <module>
# ----> 1 val_counts(df,df.columns)
#
# <ipython-input-54-300ab620dc2f> in val_counts(df, col)
#       1 def val_counts(df, col):
# ----> 2     df_vc=pd.DataFrame(df[col].value_counts())
#       3     df_vc.index.name=col
#       4     df.columns=['count']
#       5     return df_vc
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5272             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5273                 return self[name]
# -> 5274             return object.__getattribute__(self, name)
#    5275
#    5276     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'value_counts'

# %%
df[df.columns]
# Out:
#          price       condition          district  max_floor  \
# 0     130000.0  newly repaired            Center          4
# 1      65000.0            good           Arabkir          5
# 2     129000.0            good            Center         10
# 3      52000.0  newly repaired            Center         14
# 4      65000.0  newly repaired            Center         12
# ...        ...             ...               ...        ...
# 4995   56000.0            good         Davtashen         16
# 4996  115000.0            good           Arabkir          6
# 4997  127000.0  newly repaired            Center          9
# 4998   41800.0            good            Center          5
# 4999   36000.0            good  Malatia-Sebastia         14
#
#                     street  num_rooms   area  num_bathrooms building_type  \
# 0           Sayat Nova Ave          3   96.0              1         stone
# 1             Hr.Kochar St          3   78.0              1         stone
# ...
